# %%
# Dependencies
import requests
import json

# %%
# Define URL parameters
league_id = "432959547"
year = 2024

# %%
# Define cookie parameters
espn_s2 = 'AEAGstGzfVapLBUQjvAdZ6GzYXnNn%2F6zaJ1aKBaGfodSbZlAvSQCksL5cBPrQ2nvyg5B72c8fSTcMW1iUMMvVr9l9xF0WsaJz%2Fikact6HAV52u1AfskuMr1N9%2FxfssqkMhkJtnXMp3RxvVqMqvYI9GG%2FnpJBt7rTy%2BojPYRqFzOiodrozlh9%2F%2FwVppny6vLdnZMgV2RrJCbA4cGGTIWXHZJhMFFCuyrMGp6z3zoTAlGtif%2FRZCeD2gs4HQXBGPKtqzBPBeyBgiG1BJsBGmPUuv4PRKsEQibW%2Fs1ka3jCHfRUg87NAu%2B%2F6xJI1k7jX3VjVYU%3D'
    
swid = '{534A91A4-961E-4087-BE49-51DCDD461E9C}'

# %%
# Define the URL with our parameters
url = f"https://lm-api-reads.fantasy.espn.com/apis/v3/games/ffl/seasons/{year}/segments/0/leagues/{league_id}"

# %%
filters = {
    "players": {
        
        "limit": 10,
        "sortAppliedStatTotal": {
            "sortAsc": False, 
            "sortPriority": 1,
            "value": "002024"
        }
    }
}

headers = {
    'X-Fantasy-Filter': json.dumps(filters)
}

params = {
    "view": "kona_player_info",
    "leagueId" : league_id,
    "seasonId" : year,
}

player_response = requests.get(url, 
                    params=params,
                    headers=headers,
                    cookies={"swid" : swid,
                            "espn_s2" : espn_s2},)

# %%
response = requests.get("https://watsonfantasyfootball.espn.com/espnpartner/dallas/players/players_4429795_ESPNFantasyFootball_2024.json")
print(response.status_code)
print(response.json())
# Out:
# 200
# [{'ACTUAL': 17.4, 'NEXT_GAME_TIMESTAMP': '1726419600000', 'DATA_TIMESTAMP': '2024-12-30 00:00:00.000000', 'SET_END': '2024-09-17 03:59:58.000000', 'EVENT_WEEK': 1, 'OPPONENT_NAME': 'Los Angeles Rams', 'OPPOSITION_RANK': 29, 'PLAYERID': '4429795', 'FANTASY_PLAYER_ID': '4429795', 'SPORT_PLAYER_ID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'FIRST_NAME': 'Jahmyr', 'LAST_NAME': 'Gibbs', 'FULL_NAME': 'Jahmyr Gibbs', 'POSITION': 'RB', 'TEAM': '8', 'TEAM_LOCATION': 'Detroit', 'AGE': 22, 'HEIGHT': 69, 'WEIGHT': 200, 'YEARS_EXPERIENCE': 2, 'PRO_TEAM_ID': '8', 'IN_WEBHOSE': '0', 'IS_ON_INJURED_RESERVE': None, 'IS_SUSPENDED': None, 'IS_ON_BYE': None, 'IS_FREE_AGENT': None, 'CURRENT_RANK': 18, 'INJURY_STATUS_DATE': '2024-09-16 12:22:58', 'OUTSIDE_PROJECTION': 16.589690961}, {'ACTUAL': 17.6, 'NEXT_GAME_TIMESTAMP': '1727036700000', 'DATA_TIMESTAMP': '2024-12-30 00:00:00.000000', 'SET_END': '2024-09-24 03:59:45.000000', 'EVENT_WEEK': 2, 'OPPONENT_NAME': 'Tampa Bay Buccaneers', 'OPPOSITION_RANK': 27, 'PLAYERID': '4429795', 'FANTASY_PLAYER_ID': '4429795', 'SPORT_PLAYER_ID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'FIRST_NAME': 'Jahmyr', 'LAST_NAME': 'Gibbs', 'FULL_NAME': 'Jahmyr Gibbs', 'POSITION': 'RB', 'TEAM': '8', 'TEAM_LOCATION': 'Detroit', 'AGE': 22, 'HEIGHT': 69, 'WEIGHT': 200, 'YEARS_EXPERIENCE': 2, 'PRO_TEAM_ID': '8', 'IN_WEBHOSE': '0', 'IS_ON_INJURED_RESERVE': None, 'IS_SUSPENDED': None, 'IS_ON_BYE': None, 'IS_FREE_AGENT': None, 'CURRENT_RANK': 14, 'INJURY_STATUS_DATE': '2024-09-23 12:32:45', 'OUTSIDE_PROJECTION': 16.911247138}, {'ACTUAL': 16.3, 'NEXT_GAME_TIMESTAMP': '1727741700000', 'DATA_TIMESTAMP': '2024-12-30 00:00:00.000000', 'SET_END': '2024-10-01 03:59:34.000000', 'EVENT_WEEK': 3, 'OPPONENT_NAME': 'Arizona Cardinals', 'OPPOSITION_RANK': 32, 'PLAYERID': '4429795', 'FANTASY_PLAYER_ID': '4429795', 'SPORT_PLAYER_ID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'FIRST_NAME': 'Jahmyr', 'LAST_NAME': 'Gibbs', 'FULL_NAME': 'Jahmyr Gibbs', 'POSITION': 'RB', 'TEAM': '8', 'TEAM_LOCATION': 'Detroit', 'AGE': 22, 'HEIGHT': 69, 'WEIGHT': 200, 'YEARS_EXPERIENCE': 2, 'PRO_TEAM_ID': '8', 'IN_WEBHOSE': '0', 'IS_ON_INJURED_RESERVE': None, 'IS_SUSPENDED': None, 'IS_ON_BYE': None, 'IS_FREE_AGENT': None, 'CURRENT_RANK': 14, 'INJURY_STATUS_DATE': '2024-09-30 12:34:20', 'OUTSIDE_PROJECTION': 16.097182147}, {'ACTUAL': 19.8, 'NEXT_GAME_TIMESTAMP': 'None', 'DATA_TIMESTAMP': '2024-12-30 00:00:00.000000', 'SET_END': '2024-10-08 03:59:28.000000', 'EVENT_WEEK': 4, 'OPPONENT_NAME': 'Seattle Seahawks', 'OPPOSITION_RANK': 15, 'PLAYERID': '4429795', 'FANTASY_PLAYER_ID': '4429795', 'SPORT_PLAYER_ID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'FIRST_NAME': 'Jahmyr', 'LAST_NAME': 'Gibbs', 'FULL_NAME': 'Jahmyr Gibbs', 'POSITION': 'RB', 'TEAM': '8', 'TEAM_LOCATION': 'Detroit', 'AGE': 22, 'HEIGHT': 69, 'WEIGHT': 200, 'YEARS_EXPERIENCE': 2, 'PRO_TEAM_ID': '8', 'IN_WEBHOSE': '0', 'IS_ON_INJURED_RESERVE': None, 'IS_SUSPENDED': None, 'IS_ON_BYE': None, 'IS_FREE_AGENT': None, 'CURRENT_RANK': 17, 'INJURY_STATUS_DATE': '2024-10-07 12:33:03', 'OUTSIDE_PROJECTION': 14.506558776}, {'ACTUAL': None, 'NEXT_GAME_TIMESTAMP': '1728851100000', 'DATA_TIMESTAMP': '2024-12-30 00:00:00.000000', 'SET_END': '2024-10-15 03:59:15.000000', 'EVENT_WEEK': 5, 'OPPONENT_NAME': None, 'OPPOSITION_RANK': None, 'PLAYERID': '4429795', 'FANTASY_PLAYER_ID': '4429795', 'SPORT_PLAYER_ID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'FIRST_NAME': 'Jahmyr', 'LAST_NAME': 'Gibbs', 'FULL_NAME': 'Jahmyr Gibbs', 'POSITION': 'RB', 'TEAM': '8', 'TEAM_LOCATION': 'Detroit', 'AGE': 22, 'HEIGHT': 69, 'WEIGHT': 200, 'YEARS_EXPERIENCE': 2, 'PRO_TEAM_ID': '8', 'IN_WEBHOSE': '0', 'IS_ON_INJURED_RESERVE': None, 'IS_SUSPENDED': None, 'IS_ON_BYE': None, 'IS_FREE_AGENT': None, 'CURRENT_RANK': 12, 'INJURY_STATUS_DATE': '2024-10-14 12:16:12', 'OUTSIDE_PROJECTION': 0}, {'ACTUAL': 12.1, 'NEXT_GAM ...

# %%
response = requests.get("https://watsonfantasyfootball.espn.com/espnpartner/dallas/classifiers/classifiers_4429795_ESPNFantasyFootball_2024.json")
print(response.status_code)
print(response.json())
# Out:
# 200
# [{'PLAYERID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'DATA_TIMESTAMP': '2024-10-09 00:00:00.000000', 'MODEL_NAME': 'injury_model.json', 'MODEL_TYPE': 'play_with_injury_classifier', 'WEIGHT_NAME': 'injury_deeplearning.h5', 'EXECUTION_TIMESTAMP': '2024-10-08 15:46:12.000000', 'UNIQUE_LABELS': 2, 'VECTOR_SIZE': 195, 'INPUT_NODES': 3, 'EPOCHS': 10, 'BATCH_SIZE': 20, 'CLASSIFIER_RESULT': '[1, 0.5089312]', 'NORMALIZED_RESULT': 0.5089312, 'FAIR_RESULT': None}, {'PLAYERID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'DATA_TIMESTAMP': '2024-10-09 00:00:00.000000', 'MODEL_NAME': 'noinjury_model.json', 'MODEL_TYPE': 'play_without_injury_classifier', 'WEIGHT_NAME': 'noinjury_deeplearning.h5', 'EXECUTION_TIMESTAMP': '2024-10-08 15:46:12.000000', 'UNIQUE_LABELS': 2, 'VECTOR_SIZE': 195, 'INPUT_NODES': 3, 'EPOCHS': 10, 'BATCH_SIZE': 20, 'CLASSIFIER_RESULT': '[1, 0.8313331]', 'NORMALIZED_RESULT': 0.8313331, 'FAIR_RESULT': None}, {'PLAYERID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'DATA_TIMESTAMP': '2024-10-09 00:00:00.000000', 'MODEL_NAME': 'bust_model.json', 'MODEL_TYPE': 'bust_classifier', 'WEIGHT_NAME': 'bust_deeplearning.h5', 'EXECUTION_TIMESTAMP': '2024-10-08 15:46:12.000000', 'UNIQUE_LABELS': 2, 'VECTOR_SIZE': 195, 'INPUT_NODES': 3, 'EPOCHS': 10, 'BATCH_SIZE': 20, 'CLASSIFIER_RESULT': '[0, 0.53715277]', 'NORMALIZED_RESULT': 0.1833027211758692, 'FAIR_RESULT': 0.53715277}, {'PLAYERID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'DATA_TIMESTAMP': '2024-10-09 00:00:00.000000', 'MODEL_NAME': 'breakout_model.json', 'MODEL_TYPE': 'breakout_classifier', 'WEIGHT_NAME': 'breakout_deeplearning.h5', 'EXECUTION_TIMESTAMP': '2024-10-08 15:46:12.000000', 'UNIQUE_LABELS': 2, 'VECTOR_SIZE': 195, 'INPUT_NODES': 3, 'EPOCHS': 10, 'BATCH_SIZE': 20, 'CLASSIFIER_RESULT': '[0, 0.6499044]', 'NORMALIZED_RESULT': 0.10151036242419108, 'FAIR_RESULT': 0.6499043999999999}, {'PLAYERID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'DATA_TIMESTAMP': '2024-10-10 00:00:00.000000', 'MODEL_NAME': 'injury_model.json', 'MODEL_TYPE': 'play_with_injury_classifier', 'WEIGHT_NAME': 'injury_deeplearning.h5', 'EXECUTION_TIMESTAMP': '2024-10-09 14:24:12.000000', 'UNIQUE_LABELS': 2, 'VECTOR_SIZE': 195, 'INPUT_NODES': 3, 'EPOCHS': 10, 'BATCH_SIZE': 20, 'CLASSIFIER_RESULT': '[1, 0.5116323]', 'NORMALIZED_RESULT': 0.5116323, 'FAIR_RESULT': None}, {'PLAYERID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'DATA_TIMESTAMP': '2024-10-10 00:00:00.000000', 'MODEL_NAME': 'noinjury_model.json', 'MODEL_TYPE': 'play_without_injury_classifier', 'WEIGHT_NAME': 'noinjury_deeplearning.h5', 'EXECUTION_TIMESTAMP': '2024-10-09 14:24:12.000000', 'UNIQUE_LABELS': 2, 'VECTOR_SIZE': 195, 'INPUT_NODES': 3, 'EPOCHS': 10, 'BATCH_SIZE': 20, 'CLASSIFIER_RESULT': '[1, 0.8313331]', 'NORMALIZED_RESULT': 0.8313331, 'FAIR_RESULT': None}, {'PLAYERID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'DATA_TIMESTAMP': '2024-10-10 00:00:00.000000', 'MODEL_NAME': 'bust_model.json', 'MODEL_TYPE': 'bust_classifier', 'WEIGHT_NAME': 'bust_deeplearning.h5', 'EXECUTION_TIMESTAMP': '2024-10-09 14:24:12.000000', 'UNIQUE_LABELS': 2, 'VECTOR_SIZE': 195, 'INPUT_NODES': 3, 'EPOCHS': 10, 'BATCH_SIZE': 20, 'CLASSIFIER_RESULT': '[0, 0.51904917]', 'NORMALIZED_RESULT': 0.16389516959762357, 'FAIR_RESULT': 0.51904917}, {'PLAYERID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'DATA_TIMESTAMP': '2024-10-10 00:00:00.000000', 'MODEL_NAME': 'breakout_model.json', 'MODEL_TYPE': 'breakout_classifier', 'WEIGHT_NAME': 'breakout_deeplearning.h5', 'EXECUTION_TIMESTAMP': '2024-10-09 14:24:12.000000', 'UNIQUE_LABELS': 2, 'VECTOR_SIZE': 195, 'INPUT_NODES': 3, 'EPOCHS': 10, 'BATCH_SIZE': 20, 'CLASSIFIER_RESULT': '[0, 0.6453642]', 'NORMALIZED_RESULT': 0.1602554675563943, 'FAIR_RESULT': 0.6453641999999999}, {'PLAYERID': '4429795', 'EVENT_NAME': 'ES ...

# %%
response = requests.get("https://watsonfantasyfootball.espn.com/espnpartner/dallas/projections/projections_4429795_ESPNFantasyFootball_2024.json")
print(response.status_code)
print(response.json())
# Out:
# 200
# [{'PLAYERID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'DATA_TIMESTAMP': '2024-10-09 00:00:00.000000', 'MODEL_NAME': 'rb_point.pkl', 'MODEL_TYPE': 'rb_point_projection', 'EXECUTION_TIMESTAMP': '2024-10-08 15:46:12.000000', 'POLYNOMIAL_DEGREE': 1, 'SCORE_PROJECTION': 13.588433424759899, 'SCORE_DISTRIBUTION': '', 'DISTRIBUTION_NAME': 't', 'LOW_SCORE': 7.956, 'HIGH_SCORE': 17.245, 'OUTSIDE_PROJECTION': 16.274247518, 'SIMULATION_PROJECTION': 12.6}, {'PLAYERID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'DATA_TIMESTAMP': '2024-10-10 00:00:00.000000', 'MODEL_NAME': 'rb_point.pkl', 'MODEL_TYPE': 'rb_point_projection', 'EXECUTION_TIMESTAMP': '2024-10-09 14:24:12.000000', 'POLYNOMIAL_DEGREE': 1, 'SCORE_PROJECTION': 13.552411192132606, 'SCORE_DISTRIBUTION': '', 'DISTRIBUTION_NAME': 'fisk', 'LOW_SCORE': 7.437, 'HIGH_SCORE': 18.444, 'OUTSIDE_PROJECTION': 16.29294054, 'SIMULATION_PROJECTION': 12.425}, {'PLAYERID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'DATA_TIMESTAMP': '2024-10-11 00:00:00.000000', 'MODEL_NAME': 'rb_point.pkl', 'MODEL_TYPE': 'rb_point_projection', 'EXECUTION_TIMESTAMP': '2024-10-10 13:09:10.000000', 'POLYNOMIAL_DEGREE': 1, 'SCORE_PROJECTION': 14.741286330373967, 'SCORE_DISTRIBUTION': '', 'DISTRIBUTION_NAME': 'foldnorm', 'LOW_SCORE': 7.387, 'HIGH_SCORE': 20.11, 'OUTSIDE_PROJECTION': 16.291511678, 'SIMULATION_PROJECTION': 13.713}, {'PLAYERID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'DATA_TIMESTAMP': '2024-10-12 00:00:00.000000', 'MODEL_NAME': 'rb_point.pkl', 'MODEL_TYPE': 'rb_point_projection', 'EXECUTION_TIMESTAMP': '2024-10-11 14:05:12.000000', 'POLYNOMIAL_DEGREE': 1, 'SCORE_PROJECTION': 13.430765290691571, 'SCORE_DISTRIBUTION': '', 'DISTRIBUTION_NAME': 't', 'LOW_SCORE': 7.862, 'HIGH_SCORE': 17.106, 'OUTSIDE_PROJECTION': 16.291511678, 'SIMULATION_PROJECTION': 12.484}, {'PLAYERID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'DATA_TIMESTAMP': '2024-10-13 00:00:00.000000', 'MODEL_NAME': 'rb_point.pkl', 'MODEL_TYPE': 'rb_point_projection', 'EXECUTION_TIMESTAMP': '2024-10-12 12:20:29.000000', 'POLYNOMIAL_DEGREE': 1, 'SCORE_PROJECTION': 15.364152755870684, 'SCORE_DISTRIBUTION': '', 'DISTRIBUTION_NAME': 'laplace', 'LOW_SCORE': 10.384, 'HIGH_SCORE': 20.344, 'OUTSIDE_PROJECTION': 16.291892162, 'SIMULATION_PROJECTION': 15.364}, {'PLAYERID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'DATA_TIMESTAMP': '2024-10-15 00:00:00.000000', 'MODEL_NAME': 'rb_point.pkl', 'MODEL_TYPE': 'rb_point_projection', 'EXECUTION_TIMESTAMP': '2024-10-14 12:03:10.000000', 'POLYNOMIAL_DEGREE': 1, 'SCORE_PROJECTION': 13.716267180390936, 'SCORE_DISTRIBUTION': '', 'DISTRIBUTION_NAME': 't', 'LOW_SCORE': 6.503, 'HIGH_SCORE': 17.375, 'OUTSIDE_PROJECTION': 16.292502851, 'SIMULATION_PROJECTION': 11.939}, {'PLAYERID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'DATA_TIMESTAMP': '2024-10-16 00:00:00.000000', 'MODEL_NAME': 'rb_point.pkl', 'MODEL_TYPE': 'rb_point_projection', 'EXECUTION_TIMESTAMP': '2024-10-15 15:41:38.000000', 'POLYNOMIAL_DEGREE': 1, 'SCORE_PROJECTION': 13.68708478537285, 'SCORE_DISTRIBUTION': '', 'DISTRIBUTION_NAME': 't', 'LOW_SCORE': 7.956, 'HIGH_SCORE': 17.319, 'OUTSIDE_PROJECTION': 14.216042072, 'SIMULATION_PROJECTION': 12.638}, {'PLAYERID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'DATA_TIMESTAMP': '2024-10-17 00:00:00.000000', 'MODEL_NAME': 'rb_point.pkl', 'MODEL_TYPE': 'rb_point_projection', 'EXECUTION_TIMESTAMP': '2024-10-17 02:59:17.000000', 'POLYNOMIAL_DEGREE': 1, 'SCORE_PROJECTION': 13.608957804112084, 'SCORE_DISTRIBUTION': '', 'DISTRIBUTION_NAME': 't', 'LOW_SCORE': 7.956, 'HIGH_SCORE': 17.26, 'OUTSIDE_PROJECTION': 14.1407136, 'SIMULATION_PROJECTION': 12.608}, {'PLAYERID': '4429795', 'EVENT_NAME': 'ESPNFantasyFootball', 'EVENT_YEAR': '2024', 'DATA_TIMESTAMP': '2024-10-18 00:00:00.000000', 'MODEL_NAME': 'rb_point.pkl ...

# %%
print(f"Player response status Code: {player_response.status_code}")
print(player_response.headers.get("Content-Type"))
# Out:
# Player response status Code: 200
# application/json;charset=utf-8

# %%
player_json = player_response.json()
print(player_json['players'])
# Out:
# [{'draftAuctionValue': 0, 'id': 3916387, 'keeperValue': 3, 'keeperValueFuture': 4, 'lineupLocked': True, 'onTeamId': 2, 'player': {'active': True, 'defaultPositionId': 1, 'draftRanksByRankType': {'STANDARD': {'auctionValue': 13, 'published': False, 'rank': 51, 'rankSourceId': 0, 'rankType': 'STANDARD', 'slotId': 0}, 'PPR': {'auctionValue': 29, 'published': False, 'rank': 29, 'rankSourceId': 0, 'rankType': 'PPR', 'slotId': 0}}, 'droppable': False, 'eligibleSlots': [0, 7, 20, 21], 'firstName': 'Lamar', 'fullName': 'Lamar Jackson', 'id': 3916387, 'injured': False, 'injuryStatus': 'ACTIVE', 'jersey': '8', 'lastName': 'Jackson', 'lastNewsDate': 1735175321000, 'lastVideoDate': 1730229571000, 'outlooks': {'outlooksByWeek': {'1': "Lamar Jackson posted the highest yards per attempt and completion rate of his career in 2023, his first under offensive coordinator Todd Monken. That was good enough for him to win his second MVP Award and he'll now lead Baltimore into a Week 1 matchup against a stout Chiefs defense. The secondary has had some turnover between the losses of L'Jarius Sneed and Mike Edwards, but there's still athleticism at all levels of the unit. That athleticism could serve to limit Jackson's usefulness on the ground, though the Ravens will undoubtedly have to utilize an aggressive offensive approach to keep pace with Patrick Mahomes. That should lead to serviceable statistical output for Jackson to begin 2024.", '2': "Lamar Jackson was the driving force behind the Baltimore offense in Week 1, taking to the air 41 times and adding in 16 rushing attempts. A Week 2 matchup against the Raiders looks beneficial on paper, but they limited QB Justin Herbert of the Chargers to only 5.5 YPA in Week 1. Baltimore is likely to be favored and in control of the game script, limiting Jackson's need to take to the air. He's still capable of putting up a big performance, though it will likely have to come from strong efficiency and his legs, rather than the volume we saw in Week 1.", '3': "Lamar Jackson will lead a Ravens team still seeking its first win of the season into a Week 3 matchup at Dallas. Baltimore has shown a more aggressive approach than typical through the air early in the season, as Jackson has combined to throw 75 passes in the first two games. He's been disappointing from a fantasy perspective because he has only two total touchdowns, but his pace should improve as the campaign progresses. The Cowboys were beaten early through the air in Week 2 by the Saints, so Jackson should have the chance to kickstart his season in Sunday's matchup.", '4': "Lamar Jackson was limited to only 15 pass attempts in Week 3, but he still used his dynamic playmaking ability to rack up 269 total yards with a pair of scores -- the first time he's recorded multiple touchdowns in 2024. He'll almost certainly need to take to the air more in Week 4 against the Bills, who have a dynamic offense paired with a stifling defense that has limited Kyler Murray and Trevor Lawrence early this season. Though the matchup won't work in Jackson's favor, his ability to put up points with both his arms and legs keeps him locked in as an elite starting option at quarterback.", '5': "Lamar Jackson was overshadowed by Derrick Henry in Baltimore's decisive win over the Bills in Week 4, but he still showcased all of his talents with two passing touchdowns supplemented by 54 rushing yards and an additional score on the ground. He now has at least 45 rushing yards in every game, helping make up for contests during which the Ravens opt to go run-heavy due to game script. Jackson's Week 5 matchup against the division-rival Bengals has the makings of a big offensive day for both teams, and Cincinnati allowed Jayden Daniels, another dual-threat quarterback, to total 293 yards with three scores in Week 3. All told, Jackson is an elite starting option at quarterback.", '6': "Lamar Jackson showed off his playmaking ability throughout Baltimore's Week 5 shootout win over the Ben ...

# %%
year = 2024
url = f"https://lm-api-reads.fantasy.espn.com/apis/v3/games/ffl/seasons/{year}/segments/0/leagues/{league_id}"

# %%
team_id = 3

for i in range(1, 19):

    params = {
        "view": ["mRoster"],
        "leagueId" : league_id,
        "seasonId" : year,
        "scoringPeriodId": i
    }

    response = requests.get(url, 
                        params=params,
                        headers=headers,
                        cookies={"swid" : swid,
                                "espn_s2" : espn_s2},)

    json = response.json()
    print(f"Week {i}: ")
    for team in json["teams"]:
        if team["id"] != team_id:
            continue
        for player in team["roster"]["entries"]:
            if player["lineupSlotId"] not in [20, 21]:
                print(f"Started {player["playerPoolEntry"]["player"]["fullName"]}.")
            elif player["lineupSlotId"] == 20:
                print(f"Benched {player["playerPoolEntry"]["player"]["fullName"]}.")
            else:
                print(f"Had {player["playerPoolEntry"]["player"]["fullName"]} on IR.")
        print("\n")
# Out:
# Week 1:
# Started Bijan Robinson.
# Started Marvin Harrison Jr..
# Started Davante Adams.
# Started Kyle Pitts.
# Started Jordan Love.
# Started James Cook.
# Started Cooper Kupp.
# Benched Zamir White.
# Benched Christian Watson.
# Benched Raheem Mostert.
# Benched Justin Herbert.
# Started Justin Tucker.
# Benched Taysom Hill.
# Benched Tua Tagovailoa.
# Benched Jerry Jeudy.
# Started Lions D/ST.
#
#
# Week 2:
# Started Bijan Robinson.
# Started Marvin Harrison Jr..
# Started Davante Adams.
# Started Kyle Pitts.
# Benched Jordan Love.
# Started James Cook.
# Started Cooper Kupp.
# Benched Zamir White.
# Benched Christian Watson.
# Had Raheem Mostert on IR.
# Benched Justin Herbert.
# Started Justin Tucker.
# Benched Taysom Hill.
# Benched Jerry Jeudy.
# Started Commanders D/ST.
# Started Justin Fields.
#
#
# Week 3:
# Started Bijan Robinson.
# Started Marvin Harrison Jr..
# Started Davante Adams.
# Started Kyle Pitts.
# Benched Jordan Love.
# Started James Cook.
# Benched Cooper Kupp.
# Benched Zamir White.
# Benched Christian Watson.
# Had Raheem Mostert on IR.
# Benched Justin Herbert.
# Started Justin Tucker.
# Benched Taysom Hill.
# Started Jerry Jeudy.
# Benched Braelon Allen.
# Started Packers D/ST.
# Started Geno Smith.
#
#
# Week 4:
# Started Bijan Robinson.
# Started Marvin Harrison Jr..
# Benched Davante Adams.
# Started Kyle Pitts.
# Started Jordan Love.
# Started James Cook.
# Benched Cooper Kupp.
# Benched Raheem Mostert.
# Benched Taysom Hill.
# Benched Jerry Jeudy.
# Started Braelon Allen.
# Benched Geno Smith.
# Benched DeMario Douglas.
# Started Matt Prater.
# Started Raiders D/ST.
# Started DeAndre Hopkins.
#
#
# Week 5:
# Started Bijan Robinson.
# Started Marvin Harrison Jr..
# Benched Davante Adams.
# Benched Kyle Pitts.
# Started Jordan Love.
# Started James Cook.
# Had Cooper Kupp on IR.
# Benched Taysom Hill.
# Started Jerry Jeudy.
# Benched Braelon Allen.
# Benched DeAndre Hopkins.
# Started Broncos D/ST.
# Benched Trevor Lawrence.
# Benched Austin Ekeler.
# Started Tutu Atwell.
# Started Colby Parkinson.
# Started Jason Myers.
#
#
# Week 6:
# Started Bijan Robinson.
# Started Marvin Harrison Jr..
# Benched Davante Adams.
# Started Kyle Pitts.
# Started Jordan Love.
# Benched James Cook.
# Had Cooper Kupp on IR.
# Benched Taysom Hill.
# Benched Jerry Jeudy.
# Started Braelon Allen.
# Started DeAndre Hopkins.
# Benched Trevor Lawrence.
# Started Austin Ekeler.
# Benched Tutu Atwell.
# Benched Colby Parkinson.
# Started Jason Myers.
# Started Bengals D/ST.
#
#
# Week 7:
# Started Bijan Robinson.
# Started Marvin Harrison Jr..
# Started Davante Adams.
# Started Kyle Pitts.
# Started Jordan Love.
# Started James Cook.
# Benched Cooper Kupp.
# Benched Taysom Hill.
# Benched Braelon Allen.
# Benched DeAndre Hopkins.
# Benched Trevor Lawrence.
# Started Austin Ekeler.
# Benched Tutu Atwell.
# Started Jason Myers.
# Started Bengals D/ST.
# Benched Romeo Doubs.
#
#
# Week 8:
# Started Bijan Robinson.
# Started Marvin Harrison Jr..
# Benched Davante Adams.
# Started Kyle Pitts.
# Started Jordan Love.
# Started James Cook.
# Started Cooper Kupp.
# Benched Taysom Hill.
# Benched Braelon Allen.
# Benched DeAndre Hopkins.
# Benched Trevor Lawrence.
# Benched Austin Ekeler.
# Benched Tutu Atwell.
# Started Jason Myers.
# Started Romeo Doubs.
# Started Chiefs D/ST.
#
#
# Week 9:
# Started Bijan Robinson.
# Started Marvin Harrison Jr..
# Benched Davante Adams.
# Started Kyle Pitts.
# Started Jordan Love.
# Started James Cook.
# Started Cooper Kupp.
# Benched Taysom Hill.
# Benched Braelon Allen.
# Benched DeAndre Hopkins.
# Benched Austin Ekeler.
# Benched Tutu Atwell.
# Started Romeo Doubs.
# Started Patriots D/ST.
# Benched Justin Herbert.
# Started Jake Elliott.
#
#
# Week 10:
# Started Bijan Robinson.
# Started Marvin Harrison Jr..
# Started Davante Adams.
# Started Kyle Pitts.
# Benched Jordan Love.
# Started James Cook.
# Started Cooper Kupp.
# Benched Taysom Hill.
# Benched DeAndre Hopkins.
# Benched Austin Ekeler.
# Benched Romeo Doubs.
# Started Justin Herbert.
# Started Jake Elliott.
# Benched Xavier Legette.
# Benched Jalen Coker.
# Started Falcons D/ST.
#
#
# Week 11:
# Benched Marvin Harrison Jr..
# Started Davante Adams.
# Started Kyle Pitts.
# Started Jordan Love.
# Started James Cook.
# Started Cooper Kupp.
# Benched Taysom Hill.
# Started DeAndre Hopkins.
# Benched Austin Ekeler.
# Benched Romeo Doubs.
# Benched Justin Herbert.
# Started Jake Elliott.
# Benched Xavier Legette.
# Benched Jalen Coker.
# Started Packers D/ST.
# Started Derrick Henry.
#
#
# Week 12:
# Started Marvin Harrison Jr..
# Benched Davante Adams.
# Benched Jordan Love.
# Benched James Cook.
# Started Cooper Kupp.
# Benched Taysom Hill.
# Started DeAndre Hopkins.
# Started Austin Ekeler.
# Benched Romeo Doubs.
# Started Justin Herbert.
# Started Jake Elliott.
# Benched Xavier Legette.
# Benched Jalen Coker.
# Started Derrick Henry.
# Started Luke Schoonmaker.
# Started Cardinals D/ST.
#
#
# Week 13:
# Started Marvin Harrison Jr..
# Started Davante Adams.
# Benched Jordan Love.
# Started James Cook.
# Started Cooper Kupp.
# Started Taysom Hill.
# Benched DeAndre Hopkins.
# Benched Austin Ekeler.
# Benched Romeo Doubs.
# Started Justin Herbert.
# Started Jake Elliott.
# Benched Xavier Legette.
# Benched Jalen Coker.
# Started Derrick Henry.
# Benched Luke Schoonmaker.
# Started Buccaneers D/ST.
#
#
# Week 14:
# Started Marvin Harrison Jr..
# Started Davante Adams.
# Started Jordan Love.
# Started James Cook.
# Started Cooper Kupp.
# Benched Taysom Hill.
# Benched DeAndre Hopkins.
# Had Austin Ekeler on IR.
# Benched Romeo Doubs.
# Benched Justin Herbert.
# Started Jake Elliott.
# Benched Jalen Coker.
# Benched Derrick Henry.
# Started Luke Schoonmaker.
# Started Buccaneers D/ST.
# Started Bucky Irving.
#
#
# Week 15:
# Benched Marvin Harrison Jr..
# Started Davante Adams.
# Benched Jordan Love.
# Started James Cook.
# Started Cooper Kupp.
# Benched Taysom Hill.
# Benched DeAndre Hopkins.
# Had Austin Ekeler on IR.
# Benched Romeo Doubs.
# Started Justin Herbert.
# Benched Jalen Coker.
# Started Derrick Henry.
# Started Bucky Irving.
# Started Bengals D/ST.
# Started Justin Tucker.
# Started T.J. Hockenson.
#
#
# Week 16:
# Benched Marvin Harrison Jr..
# Started Davante Adams.
# Benched Jordan Love.
# Started James Cook.
# Started Cooper Kupp.
# Benched Taysom Hill.
# Benched DeAndre Hopkins.
# Had Austin Ekeler on IR.
# Benched Romeo Doubs.
# Started Justin Herbert.
# Benched Jalen Coker.
# Started Derrick Henry.
# Started Bucky Irving.
# Started Bengals D/ST.
# Started Justin Tucker.
# Started T.J. Hockenson.
#
#
# Week 17:
# Benched Marvin Harrison Jr..
# Started Davante Adams.
# Benched Jordan Love.
# Started James Cook.
# Started Cooper Kupp.
# Benched Taysom Hill.
# Benched DeAndre Hopkins.
# Had Austin Ekeler on IR.
# Benched Romeo Doubs.
# Started Justin Herbert.
# Benched Jalen Coker.
# Started Derrick Henry.
# Started Bucky Irving.
# Started Bengals D/ST.
# Started Justin Tucker.
# Started T.J. Hockenson.
#
#
# Week 18:
# Benched Marvin Harrison Jr..
# Started Davante Adams.
# Benched Jordan Love.
# Started James Cook.
# Started Cooper Kupp.
# Benched Taysom Hill.
# Benched DeAndre Hopkins.
# Had Austin Ekeler on IR.
# Benched Romeo Doubs.
# Started Justin Herbert.
# Benched Jalen Coker.
# Started Derrick Henry.
# Started Bucky Irving.
# Started Bengals D/ST.
# Started Justin Tucker.
# Started T.J. Hockenson.

# %%
print(json["teams"][0]["roster"]["entries"][0]["playerPoolEntry"])
# Out:
# {'appliedStatTotal': 0.0, 'id': 4242335, 'keeperValue': 9, 'keeperValueFuture': 1, 'lineupLocked': False, 'onTeamId': 1, 'player': {'active': True, 'defaultPositionId': 2, 'draftRanksByRankType': {'STANDARD': {'auctionValue': 51, 'published': False, 'rank': 9, 'rankSourceId': 0, 'rankType': 'STANDARD', 'slotId': 0}, 'PPR': {'auctionValue': 57, 'published': False, 'rank': 4, 'rankSourceId': 0, 'rankType': 'PPR', 'slotId': 0}}, 'droppable': False, 'eligibleSlots': [2, 3, 23, 7, 20, 21], 'firstName': 'Jonathan', 'fullName': 'Jonathan Taylor', 'id': 4242335, 'injured': False, 'injuryStatus': 'ACTIVE', 'lastName': 'Taylor', 'lastNewsDate': 1734310682000, 'lastVideoDate': 1730300793000, 'outlooks': {'outlooksByWeek': {'1': "Jonathan Taylor is healthy and ready to lead Indianapolis' backfield in Week 1 against a Texans defense that allowed the sixth-fewest rushing yards to running backs in 2023. An ankle injury landed Taylor on the PUP list amid a contract dispute to begin last season, but he produced six touchdowns in his final five appearances last season, which culminated with a 188-yard performance on the ground in a season-ending loss to Houston. Questions still linger about mobile QB Anthony Richardson's proficiency as a passer, so the Colts are expected to lean heavily on the ground game, even against the stout Texans front. Taylor faces minimal competition for backfield touches, as backup Trey Sermon is nursing a hamstring injury and third-stringer Tyler Goodson has just 87 career rushing yards.", '2': "Jonathan Taylor had an underwhelming season opener for the Colts, but he has a prime Week 2 breakout opportunity against a Packers defense that was solved for 132 scrimmage yards and three touchdowns by Saquon Barkley last week. Taylor got into the end zone in Week 1, but he averaged just 3.0 YPC on his 16 carries and didn't see a target as Anthony Richardson completed only nine passes. The three-down workhorse had fewer than 69 scrimmage yards in only one of his last eight games last season, averaging 99.4 yards per game over that span. Taylor could benefit from a more favorable game script in Week 2 after the Colts spent much of Week 1 playing catch-up as Indianapolis is likely to play from ahead against a Packers team that isn't expected to have starting QB Jordan Love (knee).", '3': "Jonathan Taylor has just 28 rushing attempts through two weeks, but he has turned those opportunities into 151 yards (5.4 yards per carry) and a TD on the ground heading into a Week 3 home game against the Bears. With Anthony Richardson struggling to throw the ball, the 0-2 Colts will likely try to ride the ground game against a Bears team that has scored only one offensive touchdown this season. Then again, that game plan also would have made sense for Week 2's game against a Packers team that had Malik Willis at QB, yet Taylor inexplicably got just 12 carries despite churning out 8.6 yards per rush. The Bears allowed 82 yards and a touchdown on the ground to Tony Pollard in Week 1 but shut down a Houston ground game led by an injured Joe Mixon (ankle) in Week 2. Taylor could also factor in more than usual as a pass catcher, as Chicago allowed the most receiving yards in the NFL to RBs last season.", '4': "Jonathan Taylor remains a set-and-forget RB1 in Week 4, even with the Colts facing a Steelers defense that has yet to allow more than 10 points in a game this season. The star RB has been the focal point of Indianapolis' offense with the team's passing game struggling, as Taylor has churned out 135 scrimmage yards in each of the last two games and has three rushing TDs through three games this season. Pittsburgh has limited RBs to 60.3 rushing yards per game and has yet to allow a TD to the position, but Taylor's impressive track record has earned him the benefit of the doubt regardless of matchup.", '5': "Jonathan Taylor will not play Week 5 vs. the Jaguars after suffering a mild high-ankle sprain in the Colts' 27-24 Week 4 win over the St ...

# %%
params = {
    "view": "mTeams",
    "leagueId" : league_id,
    "seasonId" : year,
}

team_response = requests.get(url, 
                    params=params,
                    headers=headers,
                    cookies={"swid" : swid,
                            "espn_s2" : espn_s2},)

team_json = team_response.json()
print(team_json)
# Out:
# {'gameId': 1, 'id': 432959547, 'members': [{'displayName': 'ESPNFAN7245214171', 'id': '{4623AAB6-D0B2-439F-B40A-9162CBA3558B}', 'isLeagueManager': False}, {'displayName': 'ESPNFAN5136652676', 'id': '{534A91A4-961E-4087-BE49-51DCDD461E9C}', 'isLeagueManager': False}, {'displayName': 'ESPNFAN6424975971', 'id': '{534E79E1-623C-49F7-85A9-9D9D3ECECFDA}', 'isLeagueManager': False}, {'displayName': 'ESPNFAN5720507307', 'id': '{8704B9C7-F529-4A92-9BB9-88DB582BC93D}', 'isLeagueManager': False}, {'displayName': 'espnfan14083325', 'id': '{8DE96039-858C-4A0A-BE54-58278D10E329}', 'isLeagueManager': False}, {'displayName': 'AnimeLover68', 'id': '{AAFA6FEB-5A7E-4A0E-9D38-13E7F6EC349F}', 'isLeagueManager': False}, {'displayName': 'ESPNFAN6731519042', 'id': '{AEDE1BE8-9AAA-43C7-B604-2F09D4118AE4}', 'isLeagueManager': False}, {'displayName': 'espn56756659', 'id': '{BC575520-2487-4E05-BA77-0756EFCABEAC}', 'isLeagueManager': False}, {'displayName': 'ESPNFAN6895155735', 'id': '{EC2538ED-4AAE-4B2F-9A8A-C7175263FA73}', 'isLeagueManager': False}, {'displayName': 'ESPNFAN9856489148', 'id': '{F5999DFD-BFBB-4B1B-80ED-1C589D1F6302}', 'isLeagueManager': False}], 'scoringPeriodId': 15, 'seasonId': 2024, 'segmentId': 0, 'settings': {'name': 'borg housing'}, 'status': {'currentMatchupPeriod': 15, 'isActive': True, 'latestScoringPeriod': 15}, 'teams': [{'abbrev': 'mquc', 'id': 1, 'owners': ['{BC575520-2487-4E05-BA77-0756EFCABEAC}']}, {'abbrev': 'OU', 'id': 2, 'owners': ['{534A91A4-961E-4087-BE49-51DCDD461E9C}']}, {'abbrev': 'B ', 'id': 3, 'owners': ['{8DE96039-858C-4A0A-BE54-58278D10E329}']}, {'abbrev': 'TD', 'id': 4, 'owners': ['{4623AAB6-D0B2-439F-B40A-9162CBA3558B}']}, {'abbrev': 'CY', 'id': 5, 'owners': ['{EC2538ED-4AAE-4B2F-9A8A-C7175263FA73}']}, {'abbrev': 'CDO', 'id': 6, 'owners': ['{F5999DFD-BFBB-4B1B-80ED-1C589D1F6302}']}, {'abbrev': 'BOOM', 'id': 7, 'owners': ['{AAFA6FEB-5A7E-4A0E-9D38-13E7F6EC349F}']}, {'abbrev': 'FJS', 'id': 8, 'owners': ['{8704B9C7-F529-4A92-9BB9-88DB582BC93D}']}, {'abbrev': 'LI', 'id': 9, 'owners': ['{AEDE1BE8-9AAA-43C7-B604-2F09D4118AE4}']}, {'abbrev': 'MIH', 'id': 10, 'owners': ['{534E79E1-623C-49F7-85A9-9D9D3ECECFDA}']}]}
